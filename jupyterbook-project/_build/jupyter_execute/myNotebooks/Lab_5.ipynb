# %% [markdown]
# ## **Laboratory Task 5**
#
# *John Vincent J. Gamali DS4A*
#
# ![image.png](attachment:14191b40-1c5d-4ffb-a220-7ac0d4ab15d8.png)

# %%
#1 
import torch
import numpy as np
import sys

# %%
#2 
def set_seed(seed:int):
    np.random.seed(seed)
    torch.manual_seed(seed)

# %%
set_seed(42)

# %%
#3
arr = np.random.randint(0,5, size = 6)
arr
# Out:
# array([3, 4, 2, 4, 4, 1], dtype=int32)

# %%
#4
x = torch.from_numpy(arr)
# Equivalent to x = torch.as_tensor(arr)
x
# Out:
# tensor([3, 4, 2, 4, 4, 1], dtype=torch.int32)

# %%
#5
print("past dtype:", x.dtype)
x = x.type(torch.int64)

print("x dtype changed: ", x.dtype)
# Out:
# past dtype: torch.int32
# x dtype changed:  torch.int64

# %%
#6
reshaped = x.reshape(3,2)
reshaped

#x = torch.arange(6).reshape(3,2)
#x
# Out:
# tensor([[3, 4],
#         [2, 4],
#         [4, 1]])

# %%
#7
right_col = reshaped[: , 1:]
right_col
# Out:
# tensor([[4],
#         [4],
#         [1]])

# %%
#8
x_squared = reshaped ** 2
x_squared
# Out:
# tensor([[ 9, 16],
#         [ 4, 16],
#         [16,  1]])

# %%
#9
torch.manual_seed(42)
y = torch.rand(3, 2)
print(y)
# Out:
# tensor([[0.8823, 0.9150],
#         [0.3829, 0.9593],
#         [0.3904, 0.6009]])

# %%
#10 
product = y.mul(y)
product
# Out:
# tensor([[0.7784, 0.8372],
#         [0.1466, 0.9203],
#         [0.1524, 0.3611]])
